# %%
# !pwd
# %cd /root/autodl-fs/demo/FG-DINO
# Out:
# /autodl-fs/data/demo/LLMDet
# /autodl-fs/data/demo/LLMDet
# /root/miniconda3/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('stopwords')

# %%
# !python image_demo.py images/demo.jpg \
  configs/grounding_dino_swin_t.py --weight tiny.pth \
  --text  "Bulldog . Goden Retriever" -c --pred-score-thr 0.4
# Out:
# [2025-07-10 23:19:24,546] [INFO] [real_accelerator.py:222:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /autodl-fs/data/demo/LLMDet/mmdet/evaluation/metrics/crowdhuman_metric.py:14: UserWarning: A NumPy version >=1.23.5 and <2.5.0 is required for this version of SciPy (detected version 1.23.0)
#   from scipy.sparse import csr_matrix
# Loads checkpoint by local backend from path: tiny.pth
# /root/miniconda3/lib/python3.10/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /root/miniconda3/lib/python3.10/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /root/miniconda3/lib/python3.10/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# The checkpoint seems to contain `vision_tower` weights: `mm_tunable_parts` contains `mm_vision_tower`.
# build lora at layer 0
# build lora at layer 1
# build lora at layer 2
# build lora at layer 3
# build lora at layer 4
# build lora at layer 5
# build lora at layer 6
# build lora at layer 7
# build lora at layer 8
# build lora at layer 9
# build lora at layer 10
# build lora at layer 11
# build lora at layer 12
# build lora at layer 13
# build lora at layer 14
# build lora at layer 15
# build lora at layer 16
# build lora at layer 17
# build lora at layer 18
# build lora at layer 19
# build lora at layer 20
# build lora at layer 21
# build lora at layer 22
# build lora at layer 23
# build corss attention at layer 0
# build corss attention at layer 4
# build corss attention at layer 8
# build corss attention at layer 12
# build corss attention at layer 16
# build corss attention at layer 20
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 07/10 23:19:35 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# results have been saved at outputs

# %%
# !python image_demo.py images/demo.jpeg \
  configs/grounding_dino_swin_t.py --weight tiny.pth \
  --text 'There are many apples here.' --pred-score-thr 0.35
# Out:
# [2025-05-05 15:45:53,927] [INFO] [real_accelerator.py:222:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /autodl-fs/data/demo/LLMDet/mmdet/evaluation/metrics/crowdhuman_metric.py:14: UserWarning: A NumPy version >=1.23.5 and <2.5.0 is required for this version of SciPy (detected version 1.23.0)
#   from scipy.sparse import csr_matrix
# Loads checkpoint by local backend from path: tiny.pth
# /root/miniconda3/lib/python3.10/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /root/miniconda3/lib/python3.10/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /root/miniconda3/lib/python3.10/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# The checkpoint seems to contain `vision_tower` weights: `mm_tunable_parts` contains `mm_vision_tower`.
# build lora at layer 0
# build lora at layer 1
# build lora at layer 2
# build lora at layer 3
# build lora at layer 4
# build lora at layer 5
# build lora at layer 6
# build lora at layer 7
# build lora at layer 8
# build lora at layer 9
# build lora at layer 10
# build lora at layer 11
# build lora at layer 12
# build lora at layer 13
# build lora at layer 14
# build lora at layer 15
# build lora at layer 16
# build lora at layer 17
# build lora at layer 18
# build lora at layer 19
# build lora at layer 20
# build lora at layer 21
# build lora at layer 22
# build lora at layer 23
# build corss attention at layer 0
# build corss attention at layer 4
# build corss attention at layer 8
# build corss attention at layer 12
# build corss attention at layer 16
# build corss attention at layer 20
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 05/05 15:46:02 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# noun_phrases: ['many apples']m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# results have been saved at outputs

# %%
# !python image_demo.py images/demo.jpeg \
  configs/grounding_dino_swin_t.py --weight tiny.pth \
  --text 'red apple.' --tokens-positive -1 --pred-score-thr 0.4
# Out:
# [2025-05-05 15:45:07,463] [INFO] [real_accelerator.py:222:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /autodl-fs/data/demo/LLMDet/mmdet/evaluation/metrics/crowdhuman_metric.py:14: UserWarning: A NumPy version >=1.23.5 and <2.5.0 is required for this version of SciPy (detected version 1.23.0)
#   from scipy.sparse import csr_matrix
# Loads checkpoint by local backend from path: tiny.pth
# /root/miniconda3/lib/python3.10/site-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# /root/miniconda3/lib/python3.10/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /root/miniconda3/lib/python3.10/site-packages/timm/models/helpers.py:7: FutureWarning: Importing from timm.models.helpers is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# The checkpoint seems to contain `vision_tower` weights: `mm_tunable_parts` contains `mm_vision_tower`.
# build lora at layer 0
# build lora at layer 1
# build lora at layer 2
# build lora at layer 3
# build lora at layer 4
# build lora at layer 5
# build lora at layer 6
# build lora at layer 7
# build lora at layer 8
# build lora at layer 9
# build lora at layer 10
# build lora at layer 11
# build lora at layer 12
# build lora at layer 13
# build lora at layer 14
# build lora at layer 15
# build lora at layer 16
# build lora at layer 17
# build lora at layer 18
# build lora at layer 19
# build lora at layer 20
# build lora at layer 21
# build lora at layer 22
# build lora at layer 23
# build corss attention at layer 0
# build corss attention at layer 4
# build corss attention at layer 8
# build corss attention at layer 12
# build corss attention at layer 16
# build corss attention at layer 20
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 05/05 15:45:16 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Traceback (most recent call last):
#   File "/autodl-fs/data/demo/LLMDet/image_demo.py", line 192, in <module>
#     main()
#   File "/autodl-fs/data/demo/LLMDet/image_demo.py", line 184, in main
#     inferencer(**call_args)
#   File "/autodl-fs/data/demo/LLMDet/mmdet/apis/det_inferencer.py", line 404, in __call__
#     visualization = self.visualize(
#   File "/autodl-fs/data/demo/LLMDet/mmdet/apis/det_inferencer.py", line 491, in visualize
#     self.visualizer.add_datasample(
#   File "/root/miniconda3/lib/python3.10/site-packages/mmengine/dist/utils.py", line 427, in wrapper
#     return func(*args, **kwargs)
#   File "/autodl-fs/data/demo/LLMDet/mmdet/visualization/local_visualizer.py", line 468, in add_datasample
#     pred_img_data = self._draw_instances(image, pred_instances,
#   File "/autodl-fs/data/demo/LLMDet/mmdet/visualization/local_visualizer.py", line 159, in _draw_instances
#     self.draw_texts(
#   File "/root/miniconda3/lib/python3.10/site-packages/mmengine/dist/utils.py", line 427, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.10/site-packages/mmengine/visualization/visualizer.py", line 504, in draw_texts
#     assert positions.shape == (num_text, 2), (
# AssertionError: `positions` should have the shape of (7, 2), but got (1, 2)
