# %%
messages = [
    {
        "role": "user",
        "content": [
            {"type": "image", "image": image_path},
            {"type": "text", "text": f"""
Objective:
Analyze the given image and extract visually distinctive attributes for objects belonging to the following categories:
{tags}

Attribute Guidelines (List only clearly visible and most distinctive attributes, in order of priority):

1. Object type/subcategory (e.g., smartphone, hardcover book)
2. Appearance (shape/size/notable features)
3. Material/texture (e.g., glossy, matte, fabric)
4. Components (attached parts, e.g., strap on handbag)
5. Color scheme (dominant colors/patterns)
6. Interaction Status (usage mode, e.g., held, open)
7. Surface text/graphics (visible logos/labels)
8. Spatial location (approximate position in the frame)
9. Adjacent objects (only include core objects with stable positional relationships)

Rules:
- Only include categories that are present in the image.
- List only attributes that are visually confirmed. Do not guess or assume.
- For multiple instances of the same category, describe the most prominent or clearly visible one.
- Limit each object's attributes to a maximum of 10.
- Do not describe the absence of something (e.g., "no visible label" should not be included unless it's a critical identifying feature).
- Select the most significant visual features from the 9 attribute categories, prioritizing those with high visual distinctiveness over those with low category relevance. A single attribute in the description may correspond to multiple attribute categories if it is visually prominent.
- Organize the output in a structured format, suitable for inclusion in a JSON string.

Example Outputs:
[Suitcase]: ["hardshell"], ["navy blue"], ["on airport cart"], ["rectangular"], ["scratches"], ["wheeled"], ["with retractable handle"]
[Laptop]: ["gaming laptop"], ["RGB keyboard"], ["half-open"], ["next to mousepad"], ["'GTX' sticker on lid"]
"""}
        ]
    }
]

# %% [markdown]
# ## 0、准备

# %%
import os
import torch

from transformers import Qwen2_5_VLForConditionalGeneration, AutoProcessor
from qwen_vl_utils import process_vision_info

model_path = "/root/models/Qwen2.5-VL-7B-Instruct/" #"Qwen/Qwen2.5-VL-7B-Instruct"
assert os.path.exists(model_path)

model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
    model_path,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    attn_implementation="flash_attention_2",
)

#模型中每幅图像的视觉标记数量的默认范围为 4-16384。
#您可以根据需要设置 min_pixels 和 max_pixels，例如 256-1280 的 token 范围，以平衡性能和显存占用
processor = AutoProcessor.from_pretrained(
    model_path,
    # min_pixels=256*28*28, max_pixels=1280*28*28,
)

print('\n模型加载完毕！')
# Out:
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# 模型加载完毕！

# %% [markdown]
# ## 1、基本

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img_path = "/root/autodl-fs/demo/grounding_data/coco/train2017/000000272026.jpg"
# 展示图片
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')
plt.show()
messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
                # 图片可以是 URL、本地图片路径、base64编码（data:image;base64......）
                "image": img_path,
            },
            {"type": "text", "text": """
Objective:
Analyze images and extract visually distinctive attributes for objects belonging to these categories:
[  "wall"]

Attribute Guidelines (List only clearly visible and most distinctive attributes, in order of priority):

1. Object type/subcategory (e.g., smartphone, hardcover book)
2. Appearance (shape/size/notable features)
3. Material/texture (e.g., glossy, matte, fabric)
4. Components (attached parts, e.g., strap on handbag)
5. Color scheme (dominant colors/patterns)
6. Interaction Status (usage mode, e.g., held, open)
7. Surface text/graphics (visible logos/labels)
8. Spatial location (approximate position in the frame)
9. Adjacent objects (only include core objects with stable positional relationships)

Rules:
- Only include categories that are present in the image.
- List only attributes that are visually confirmed. Do not guess or assume.
- For multiple instances of the same category, describe the most prominent or clearly visible one.
- Limit each object's attributes to a maximum of 10.
- Do not describe the absence of something (e.g., "no visible label" should not be included unless it's a critical identifying feature).
- Select the most significant visual features from the 9 attribute categories, prioritizing those with high visual distinctiveness over those with low category relevance. A single attribute in the description may correspond to multiple attribute categories if it is visually prominent.
- Organize the output in a structured format as example

Example Outputs:
[Suitcase]: ["hardshell"], ["navy blue"], ["on airport cart"], ["rectangular"], ["scratches"], ["wheeled"], ["with retractable handle"]
[Laptop]: ["gaming laptop"], ["RGB keyboard"], ["half-open"], ["next to mousepad"], ["'GTX' sticker on lid"]
"""},
        ],
    }
]

# Preparation for inference
text = processor.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
)
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=[text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
)
inputs = inputs.to(model.device)

# Inference: Generation of the output
generated_ids = model.generate(**inputs, max_new_tokens=128)
generated_ids_trimmed = [
    out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
]
output_text = processor.batch_decode(
    generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
)

print('\n回答：\n', output_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 54
#      10 messages = [
#      11     {
#      12         "role": "user",
#    (...)
#      50     }
#      51 ]
#      53 # Preparation for inference
# ---> 54 text = processor.apply_chat_template(
#      55     messages, tokenize=False, add_generation_prompt=True
#      56 )
#      57 image_inputs, video_inputs = process_vision_info(messages)
#      58 inputs = processor(
#      59     text=[text],
#      60     images=image_inputs,
#    (...)
#      63     return_tensors="pt",
#      64 )
#
# NameError: name 'processor' is not defined

# %% [markdown]
# ## 2、获取json并进行推理

# %%
import json
import os
 
def count_jsonl_lines(file_path):
    """计算JSONL文件的总行数"""
    with open(file_path, 'r', encoding='utf-8') as f:
        return sum(1 for _ in f)
# 读取 JSONL 文件的函数
def read_jsonl_batch(file_path, batch_size):
    """
    按批次读取 JSONL 文件
    :param file_path: JSONL 文件路径
    :param batch_size: 每批数据的大小
    :yield: 每一批数据（列表形式）
    """
    batch = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            try:
                parsed_line = json.loads(line.strip())
                batch.append(parsed_line)
                if len(batch) == batch_size:
                    yield batch
                    batch = []
            except json.JSONDecodeError:
                print(f"JSON 解析错误，已跳过该行: {line}")
        if batch:
            yield batch

# 使用 Qwen2.5 模型进行属性识别
def identify_attributes(tags, image_path):
    messages = [
        {
            "role": "user",
            "content": [
                {"type": "image", "image": image_path},
                {"type": "text", "text": f"""
Objective:
Analyze images and extract visually distinctive attributes for objects belonging to these categories:
Target Categories: {tags}

Attribute Priority (0-1 weight score, 0=exclude, 1=definitive):
Distinctive Visual Features (e.g., ribbed bottle, stemmed wine glass)
Color Scheme (dominant hues, patterns)
Spatial Position (precise frame location)
Shape & Size (notable proportions)
Material/Texture (glossy, matte, woven)
Attached Components (removable parts)
Usage Status (dynamic interactions)
Visible Text/Graphics (logos, labels)
Adjacent Objects (proximity relationships)

Rules:
Omit categories not present in the image.
Only include attributes verifiable by visual cues (no inference).
For each object in the category list, must output attributes ()
For unrecognizable objects, use [Object Category]: [unknown (0)] with at least 1 attribute
Each object must list at least 5 attributes (inferred attributes allowed with weight ≤0.4)
Output Format:
[Object Category]: [Attribute 1 (weight)], [Attribute 2 (weight)], ...

Examples:
**Invalid Example (Do Not Imitate):**  
[Cup]: [clear glass cup with handle (0.8), placed on table (0.7), possibly containing water or another liquid ( 

**Valid Example:**  
[Dog]: [golden retriever with white paws (0.9)], [sitting on red couch (0.7)], [wearing blue collar (0.5)], [tongue out (0.3)], [front paws on floor (0.4)], [looking at camera (0.4)]
[Car]: [metallic silver sedan (0.85)], [parked 50cm from garage door (0.7)], [tinted windows (0.4)], ["BMW" logo (0.9)], [four-door design (0.6)], [shiny hubcaps (0.5)]
[Cat]: [calico cat with black spots (0.9)], [staring at bird feeder (0.8)], [on wooden windowsill (0.6)], [pointed ears (0.4)], [bushy tail (0.5)], [paw raised (0.4)]
[Chair]: [unknown（0）]
"""}
            ]
        }
    ]

    text = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    image_inputs, video_inputs = process_vision_info(messages)
    inputs = processor(
        text=[text],
        images=image_inputs,
        videos=video_inputs,
        padding=True,
        return_tensors="pt",
    )
    inputs = inputs.to(model.device)

    generated_ids = model.generate(**inputs, max_new_tokens=128)
    generated_ids_trimmed = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
    ]
    output_text = processor.batch_decode(
        generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
    )
    return output_text[0]



"""
解析属性文本
"""
def parse_attributes(attributes_text):
    attribute_dict = {}
    # 按行分割，过滤空行
    lines = [line.strip() for line in attributes_text.split('\n') if line.strip()]
    
    for line in lines:
        if line.startswith('[') and ']: [' in line:
            # 分割对象和属性
            obj_part, attrs_part = line.split(']: [', 1)
            obj = obj_part[1:]  # 去掉开头的[
            attrs = attrs_part[:-1].split('], [')  # 去掉结尾的]并分割属性
            attribute_dict[obj] = attrs
            print(attrs)
    return attribute_dict


# if __name__ == '__main__':
#      str=" ['[Sky]: [overcast], [gray], [covering the top half of the image], [cloudy], [uniformly gray], [no distinct features], [no visible stars or sun]\n[People]: [small figures], [standing near vehicles], [distant], [human-like shapes], [clothing], [moving], [near kites]\n[Pavement]: [dirt road], [brown], [in foreground], [straight], [rough texture], [no markings], [adjacent to sand]\n[Sand]: [beach], [brown], [extending from foreground to background], [flat], [']"
#      temp=parse_attributes(str)
#      print(temp)


# 更新 JSONL 文件，添加 attributes 字段
def update_jsonl_batch(data, image_base_path, output_file_path):
    with open(output_file_path, 'a', encoding='utf-8') as f:
        for item in data:
            filename = item['filename']
            image_path = f"{image_base_path}/{filename}"
            
            for region in item['grounding']['regions']:
                phrase = region['phrase']
                attributes_text = identify_attributes(phrase, image_path)
                attribute_dict = parse_attributes(attributes_text)
                print(attributes_text)
                region['attributes'] = attribute_dict
         
            
            print(item)
            f.write(json.dumps(item) + '\n')

def main():
    file_path = '/root/autodl-fs/demo/grounding_data/coco/annotations/instances_train2017_vg_merged6.jsonl'
    image_base_path = '/root/autodl-fs/demo/grounding_data/coco/train2017'
    output_file_path = '/root/autodl-fs/demo/grounding_data/coco/annotations/instances_train2017_vg_merged6_with_attributes.jsonl'
    
    # 计算总标注数
    total_annotations = count_jsonl_lines(file_path)
    print(f"总标注数: {total_annotations}")
    
    batch_size = 100
    processed_count = 0
    
    # 清空或创建输出文件
    with open(output_file_path, 'w', encoding='utf-8') as f:
        pass
    
    for batch in read_jsonl_batch(file_path, batch_size):
        update_jsonl_batch(batch, image_base_path, output_file_path)
        
        processed_count += len(batch)
        progress = (processed_count / total_annotations) * 100
        print(f"已处理 {processed_count}/{total_annotations} 个标注 ({progress:.2f}%)")
 
if __name__ == '__main__':
    main()
# Out:
# 总标注数: 205815
# ['"alcohol bottle"', '"dark glass body"', '"label visible"', '"on table"', '"partially obscured by glassware"']
# [Bottle]: ["alcohol bottle"], ["dark glass body"], ["label visible"], ["on table"], ["partially obscured by glassware"]
# ['"wooden", "rectangular"', '"brown"', '"smooth"', '"with glassware and napkins"', '"wooden"', '"centered"', '"with people sitting around"', '"with drinks and glasses"', '"under people"']
# [Dining Table]: ["wooden", "rectangular"], ["brown"], ["smooth"], ["with glassware and napkins"], ["wooden"], ["centered"], ["with people sitting around"], ["with drinks and glasses"], ["under people"]
# ['"smiling"', '"wearing white blazer"', '"blonde hair"', '"sitting at table"', '"wearing black top"', '"holding glass"', '"at restaurant"', '"with two other people"']
# [Person]: ["smiling"], ["wearing white blazer"], ["blonde hair"], ["sitting at table"], ["wearing black top"], ["holding glass"], ["at restaurant"], ["with two other people"]
# ['"glass", "tall", "clear", "on wooden table"', '"water", "inside"', '"reflective surface"', '"on table near center"', '"adjacent to bottle"']
# [Cup]: ["glass", "tall", "clear", "on wooden table"], ["water", "inside"], ["reflective surface"], ["on table near center"], ["adjacent to bottle"]
# ['"stemmed", "clear", "glossy", "on table"', '"on table"', '"next to bottle"']
# [wine glass]: ["stemmed", "clear", "glossy", "on table"], ["on table"], ["next to bottle"]
# ['"wooden"', '"dark brown"', '"partially visible behind woman on left"', '"slightly curved backrest"', '"textured seat"', '"behind table"']
# [Chair]: ["wooden"], ["dark brown"], ["partially visible behind woman on left"], ["slightly curved backrest"], ["textured seat"], ["behind table"]
# ['"chalkboard"', '"black"', '"text written"', '"menu items"', '"list of food options"', '"in background"', '"above table"']
# [Wall]: ["chalkboard"], ["black"], ["text written"], ["menu items"], ["list of food options"], ["in background"], ["above table"]
# {'filename': '000000272026.jpg', 'height': 480, 'width': 640, 'conversations': [{'from': 'human', 'value': '\nProvide a scene graph caption of the given image.'}, {'from': 'gpt', 'value': 'In the image, three women are sitting at a dining table. They appear to be enjoying themselves, with one leaning on the table and all of them in front of it. The table has several cups and bottles on it, suggesting that they are enjoying drinks. One of the women is beside a wall, and two of the women are beside each other. There is also a chair visible in the image, indicating that they are seated. The setting appears to be a restaurant or a similar dining establishment.'}], 'tags': ['table', 'wall', 'caption', 'restaurant', 'dining establishment'], 'grounding': {'caption': 'keyboard. toaster. hair drier. tennis racket. bicycle. person. tv. cow. parking meter. couch. horse. cell phone. vase. sports ball. umbrella. airplane. apple. donut. suitcase. microwave. laptop. refrigerator. baseball bat. fork. orange. backpack. tie. sheep. bear. toothbrush. cup. motorcycle. snowboard. bed. bird. cake. sandwich. sink. teddy bear. skis. giraffe. bus. carrot. skateboard. potted plant. stop sign. dining table. wine glass. train. boat. bowl. surfboard. book. scissors. clock. fire hydrant. truck. bottle. toilet. spoon. mouse. car. traffic light. knife. kite. zebra. hot dog. elephant. cat. frisbee. baseball glove. pizza. handbag. chair. dog. bench. remote. oven. banana. broccoli. wall. restaurant. dining establishment. ', 'regions': [{'bbox': [[256.49, 255.39, 288.16, 348.46], [354.01, 287.67, 372.15, 347.32]], 'phrase': 'bottle', 'tokens_positive': [[515, 521]], 'attributes': {'Bottle': ['"alcohol bottle"', '"dark glass body"', '"label visible"', '"on table"', '"partially obscured by glassware"']}}, {'bbox': [224.36, 233.06, 526.38, 456.34000000000003], 'phrase': 'dining table', 'tokens_positive': [[415, 427]], 'attributes': {'Dining Table': ['"wooden", "rectangular"', '"brown"', '"smooth"', '"with glassware and napkins"', '"wooden"', '"centered"', '"with people sitting around"', '"with drinks and glasses"', '"under people"']}}, {'bbox': [[351.46, 107.15, 503.67999999999995, 334.26], [415.09, 121.06, 640.0, 479.73], [43.85, 119.7, 410.07000000000005, 480.0]], 'phrase': 'person', 'tokens_positive': [[55, 61]], 'attributes': {'Person': ['"smiling"', '"wearing white blazer"', '"blonde hair"', '"sitting at table"', '"wearing black top"', '"holding glass"', '"at restaurant"', '"with two other people"']}}, {'bbox': [[332.78, 321.94, 359.76, 356.27], [373.54, 340.64, 427.11, 407.48], [295.03, 301.73, 331.59999999999997, 345.89]], 'phrase': 'cup', 'tokens_positive': [[277, 280]], 'attributes': {'Cup': ['"glass", "tall", "clear", "on wooden table"', '"water", "inside"', '"reflective surface"', '"on table near center"', '"adjacent to bottle"']}}, {'bbox': [390.74, 314.1, 432.97, 341.01000000000005], 'phrase': 'wine glass', 'tokens_positive': [[429, 439]], 'attributes': {'wine glass': ['"stemmed", "clear", "glossy", "on table"', '"on table"', '"next to bottle"']}}, {'bbox': [19.44, 397.63, 62.480000000000004, 480.0], 'phrase': 'chair', 'tokens_positive': [[650, 655]], 'attributes': {'Chair': ['"wooden"', '"dark brown"', '"partially visible behind woman on left"', '"slightly curved backrest"', '"textured seat"', '"behind table"']}}, {'bbox': [0.390380859375, 0.3515625, 166.625, 477.5], 'phrase': 'wall', 'tokens_positive': [[701, 705]], 'attributes': {'Wall': ['"chalkboard"', '"black"', '"text written"', '"menu items"', '"list of food options"', '"in background"', '"above table"']}}]}}
# ['"smartphone"', '"purple"', '"in hand"', '"held"', '"texting"', '"on lap"', '"next to person"']
# [Cell phone]: ["smartphone"], ["purple"], ["in hand"], ["held"], ["texting"], ["on lap"], ["next to person"]
# ['"reading book"', '"black jacket"', '"blue jeans"', '"sitting on bleachers"', '"holding book open"', '"reading posture"', '"on right side of image"', '"backpack nearby"']
# [Person sitting on steps]: ["reading book"], ["black jacket"], ["blue jeans"], ["sitting on bleachers"], ["holding book open"], ["reading posture"], ["on right side of image"], ["backpack nearby"]
# ['"plastic", "clear", "with blue cap"', '"on steps near person reading"', '"next to black jacket"']
# [Bottle]: ["plastic", "clear", "with blue cap"], ["on steps near person reading"], ["next to black jacket"]
# ['"black"', '"textured fabric"', '"on person\'s lap"', '"closed"', '"purple scarf nearby"', '"on stadium steps"', '"adjacent to water bottle"']
# [Handbag]: ["black"], ["textured fabric"], ["on person's lap"], ["closed"], ["purple scarf nearby"], ["on stadium steps"], ["adjacent to water bottle"]
# ['"hardcover book"', '"open"', '"reading"', '"black cover"', '"in man\'s hands"', '"on bleachers"', '"next to water bottle"']
# [Book]: ["hardcover book"], ["open"], ["reading"], ["black cover"], ["in man's hands"], ["on bleachers"], ["next to water bottle"]
# ['"metallic", "gray", "tiered", "outdoor seating", "with railings"', '"occupied by people"', '"in sunlight"', '"adjacent to steps"']
# ['"black"', '"on steps"', '"near woman"']
# [Stadium Seating]: ["metallic", "gray", "tiered", "outdoor seating", "with railings"], ["occupied by people"], ["in sunlight"], ["adjacent to steps"]
#
# [People]:
# 1. ["woman sitting"], ["wearing black jacket and purple scarf"], ["holding smartphone"], ["texting"], ["on steps"], ["adjacent to backpack"]
# 2. ["man sitting"], ["wearing black jacket and jeans"], ["reading book"], ["on steps"], ["adjacent to woman"]
#
# [Backpack]: ["black"], ["on steps"], ["near woman"]
# {'filename': '000000422170.jpg', 'height': 548, 'width': 640, 'conversations': [{'from': 'human', 'value': '\nProvide a scene graph caption of the given image.'}, {'from': 'gpt', 'value': 'In the image, several people are interacting with the stairs of the bleachers in different ways. One person is sitting on the stairs and is holding a book. Another person is sitting on the stairs and is holding and looking at a cell phone. Two other individuals appear to be walking on the stairs, with one of them looking at something in the distance. There is a handbag and a bottle placed on the stairs, indicating the presence of spectators or passersby who have settled there temporarily. The setting is outdoors, and the bleachers are bathed in sunlight.'}], 'tags': ['people', 'presence', 'caption', 'something', 'outdoors', 'sunlight', 'ways'], 'grounding': {'caption': 'person. handbag. orange. microwave. keyboard. boat. cat. skateboard. tennis racket. tie. clock. bus. cake. carrot. traffic light. tv. oven. frisbee. donut. bowl. elephant. airplane. train. cell phone. couch. sink. umbrella. skis. stop sign. dog. mouse. sports ball. broccoli. toothbrush. sheep. baseball bat. cow. bench. fork. horse. scissors. vase. parking meter. apple. remote. bed. toilet. hair drier. cup. fire hydrant. bear. zebra. laptop. potted plant. dining table. suitcase. chair. hot dog. giraffe. backpack. kite. book. refrigerator. knife. teddy bear. motorcycle. spoon. baseball glove. surfboard. toaster. wine glass. bicycle. car. sandwich. truck. pizza. bottle. snowboard. banana. bird. outdoors. presence. something. sunlight. ways. ', 'regions': [{'bbox': [160.68, 350.7, 181.84, 362.45], 'phrase': 'cell phone', 'tokens_positive': [[189, 199]], 'attributes': {'Cell phone': ['"smartphone"', '"purple"', '"in hand"', '"held"', '"texting"', '"on lap"', '"next to person"']}}, {'bbox': [[0.0, 3.68, 144.49, 360.65000000000003], [445.49, 64.62, 640.0, 389.86], [49.26, 258.61, 284.47, 518.44], [407.61, 1.23, 498.74, 176.1], [0.0, 145.43, 28.1, 249.26]], 'phrase': 'person', 'tokens_positive': [[0, 6]], 'attributes': {'Person sitting on steps': ['"reading book"', '"black jacket"', '"blue jeans"', '"sitting on bleachers"', '"holding book open"', '"reading posture"', '"on right side of image"', '"backpack nearby"']}}, {'bbox': [400.25, 456.28, 452.38, 472.29999999999995], 'phrase': 'bottle', 'tokens_positive': [[668, 674]], 'attributes': {'Bottle': ['"plastic", "clear", "with blue cap"', '"on steps near person reading"', '"next to black jacket"']}}, {'bbox': [146.8, 471.41, 254.53000000000003, 548.0], 'phrase': 'handbag', 'tokens_positive': [[8, 15]], 'attributes': {'Handbag': ['"black"', '"textured fabric"', '"on person\'s lap"', '"closed"', '"purple scarf nearby"', '"on stadium steps"', '"adjacent to water bottle"']}}, {'bbox': [427.19, 225.4, 515.87, 264.69], 'phrase': 'book', 'tokens_positive': [[524, 528]], 'attributes': {'Book': ['"hardcover book"', '"open"', '"reading"', '"black cover"', '"in man\'s hands"', '"on bleachers"', '"next to water bottle"']}}, {'bbox': [0.78173828125, 0.802734375, 639.0, 546.0], 'phrase': 'outdoors', 'tokens_positive': [[701, 709]], 'attributes': {'Stadium Seating': ['"metallic", "gray", "tiered", "outdoor seating", "with railings"', '"occupied by people"', '"in sunlight"', '"adjacent to steps"'], 'Backpack': ['"black"', '"on steps"', '"near woman"']}}]}}
# ['"foldable"', '"red frame"', '"black tires"', '"white wheels"', '"blue accents"', '"held upright"', '"on sidewalk"', '"adjacent to person"']
# [Bicycle]: ["foldable"], ["red frame"], ["black tires"], ["white wheels"], ["blue accents"], ["held upright"], ["on sidewalk"], ["adjacent to person"]
# ```json
# [
#     {
#         "person": ["wearing helmet"],
#         "appearance": ["smiling"],
#         "color scheme": ["white shirt"],
#         "interaction status": ["standing"],
#         "surface text/graphics": ["Mizuno logo"],
#         "spatial location": ["center"],
#         "adjacent objects": ["bicycle"]
#     },
#     {
#         "person": ["wearing helmet"],
#         "appearance": ["smiling"],
#         "color scheme": ["orange shirt"],
#         "interaction status": ["standing"],
#         "surface text/graphics": ["'plaudisse'"],
#         "spatial
# ['"black"', '"on person\'s back"', '"textured fabric"', '"with straps"', '"on right side of image"', '"partially obscured by person"', '"on person wearing white shirt"']
# ```json
# [Backpack]: ["black"], ["on person's back"], ["textured fabric"], ["with straps"], ["on right side of image"], ["partially obscured by person"], ["on person wearing white shirt"]
# ```
# ['"plastic stool"', '"white"', '"under table"', '"simple design"', '"in background"']
# [Chair]: ["plastic stool"], ["white"], ["under table"], ["simple design"], ["in background"]
# ['"outdoor table"', '"with chairs"', '"under awning"', '"wooden surface"', '"surrounded by people"', '"in background"', '"partially obscured by people"']
# [Dining Table]: ["outdoor table"], ["with chairs"], ["under awning"], ["wooden surface"], ["surrounded by people"], ["in background"], ["partially obscured by people"]
# ['"green foliage"', '"bushy"', '"in background"', '"partially obscured by people"', '"leaves visible"', '"near sidewalk"', '"behind individuals"']
# [Tree]: ["green foliage"], ["bushy"], ["in background"], ["partially obscured by people"], ["leaves visible"], ["near sidewalk"], ["behind individuals"]
# ['"multi-story"', '"brick facade"', '"overhangs"', '"entrance with glass doors"', '"greenery around"', '"adjacent to sidewalk"', '"partially visible"']
# [Building]: ["multi-story"], ["brick facade"], ["overhangs"], ["entrance with glass doors"], ["greenery around"], ["adjacent to sidewalk"], ["partially visible"]
# ['"foldable"', '"red frame"', '"black wheels"', '"white handlebars"', '"blue seat"', '"on sidewalk"', '"adjacent to riders"']
# [Bicycle]: ["foldable"], ["red frame"], ["black wheels"], ["white handlebars"], ["blue seat"], ["on sidewalk"], ["adjacent to riders"]
# ['"wet", "gray", "slippery", "curved edge", "brick border"']
# [Pavement]: ["wet", "gray", "slippery", "curved edge", "brick border"]
# {'filename': '000000440284.jpg', 'height': 480, 'width': 640, 'conversations': [{'from': 'human', 'value': '\nProvide a scene graph caption of the given image.'}, {'from': 'gpt', 'value': 'In the image, three men are standing next to their bicycles. Two of the men are carrying backpacks, and all three are touching their respective bicycles. The bicycles are parked on the pavement. Two of the bicycles are beside each other. The setting includes a tree and a building in the background, with a roof visible at the top of the image. The men are wearing casual clothing and helmets, suggesting they are ready for a bike ride.'}], 'tags': ['building', 'tree', 'caption', 'men', 'clothing', 'pavement', 'roof visible', 'bike ride'], 'grounding': {'caption': 'orange. clock. tennis racket. remote. horse. knife. keyboard. oven. parking meter. tie. person. bottle. fork. snowboard. dog. suitcase. toothbrush. carrot. baseball bat. donut. car. hair drier. microwave. sheep. chair. umbrella. broccoli. kite. refrigerator. vase. motorcycle. backpack. fire hydrant. tv. cell phone. wine glass. toaster. cake. pizza. traffic light. sink. hot dog. sandwich. bird. elephant. dining table. airplane. laptop. bus. teddy bear. bowl. book. apple. bicycle. cat. sports ball. surfboard. spoon. potted plant. scissors. boat. pavement. building. roof visible. tree. ', 'regions': [{'bbox': [[390.48, 146.81, 515.95, 382.47], [80.86, 186.35, 226.0, 457.97], [267.35, 182.54, 375.74, 392.09000000000003], [193.03, 186.67, 295.23, 404.47], [3.26, 122.8, 75.05000000000001, 181.26999999999998]], 'phrase': 'bicycle', 'tokens_positive': [[475, 482]], 'attributes': {'Bicycle': ['"foldable"', '"red frame"', '"black tires"', '"white wheels"', '"blue accents"', '"held upright"', '"on sidewalk"', '"adjacent to person"']}}, {'bbox': [[300.67, 53.8, 394.09000000000003, 350.17], [443.9, 45.86, 527.26, 344.48], [44.51, 96.49, 80.47999999999999, 146.14999999999998], [93.84, 96.88, 117.14, 161.26], [0.07, 86.49, 23.69, 135.28], [11.95, 84.48, 31.68, 122.85], [110.0, 28.13, 220.0, 415.63], [191.95, 83.81, 209.02999999999997, 102.02000000000001]], 'phrase': 'person', 'tokens_positive': [[88, 94]], 'attributes': {}}, {'bbox': [[458.02, 95.58, 530.6, 195.38], [134.4, 84.48, 145.1, 167.55]], 'phrase': 'backpack', 'tokens_positive': [[277, 285]], 'attributes': {'Backpack': ['"black"', '"on person\'s back"', '"textured fabric"', '"with straps"', '"on right side of image"', '"partially obscured by person"', '"on person wearing white shirt"']}}, {'bbox': [274.89, 136.09, 295.31, 161.33], 'phrase': 'chair', 'tokens_positive': [[212, 217]], 'attributes': {'Chair': ['"plastic stool"', '"white"', '"under table"', '"simple design"', '"in background"']}}, {'bbox': [59.06, 112.51, 114.6, 162.69], 'phrase': 'dining table', 'tokens_positive': [[407, 419]], 'attributes': {'Dining Table': ['"outdoor table"', '"with chairs"', '"under awning"', '"wooden surface"', '"surrounded by people"', '"in background"', '"partially obscured by people"']}}, {'bbox': [550.5, 0.1171875, 610.5, 126.625], 'phrase': 'tree', 'tokens_positive': [[584, 588]], 'attributes': {'Tree': ['"green foliage"', '"bushy"', '"in background"', '"partially obscured by people"', '"leaves visible"', '"near sidewalk"', '"behind individuals"']}}, {'bbox': [0.3125, 0.234375, 639.0, 157.625], 'phrase': 'building', 'tokens_positive': [[560, 568]], 'attributes': {'Building': ['"multi-story"', '"brick facade"', '"overhangs"', '"entrance with glass doors"', '"greenery around"', '"adjacent to sidewalk"', '"partially visible"']}}, {'bbox': [161.375, 0.05859375, 640.0, 33.25], 'phrase': 'roof visible', 'tokens_positive': [[570, 582]], 'attributes': {'Bicycle': ['"foldable"', '"red frame"', '"black wheels"', '"white handlebars"', '"blue seat"', '"on sidewalk"', '"adjacent to riders"']}}, {'bbox': [0.9375, 332.25, 638.5, 478.5], 'phrase': 'pavement', 'tokens_positive': [[550, 558]], 'attributes': {'Pavement': ['"wet", "gray", "slippery", "curved edge", "brick ...
# ['"tall", "spotted pattern", "standing", "brown and white", "feeding area", "rocky enclosure", "three individuals", "outdoors"']
# [Giraffe]: ["tall", "spotted pattern", "standing", "brown and white", "feeding area", "rocky enclosure", "three individuals", "outdoors"]
# {'filename': '000000257958.jpg', 'height': 480, 'width': 640, 'conversations': [{'from': 'human', 'value': '\nProvide a scene graph caption of the given image.'}, {'from': 'gpt', 'value': 'In the image, three giraffes are seen in close proximity to each other, with two of them beside one another and the third one beside the second. The giraffes are of varying sizes and appear to be engaged in feeding. One of the giraffes is eating from a patch of grass, while the others are looking at the grass or each other. The scene includes a large rock formation, with the giraffes beside it, and one giraffe in front of the rock. A tree is also present in the image, in front of one of the giraffes and beside the rock formation.'}], 'tags': ['grass', 'tree', 'caption', 'sizes', 'patch', 'rock', 'proximity', 'rock formation'], 'grounding': {'caption': 'umbrella. book. toothbrush. bicycle. oven. sports ball. parking meter. cake. motorcycle. banana. giraffe. truck. person. frisbee. knife. traffic light. microwave. surfboard. wine glass. bottle. laptop. bowl. elephant. tie. bus. boat. cell phone. sandwich. orange. car. airplane. carrot. fork. sink. sheep. chair. dog. broccoli. refrigerator. toaster. apple. bed. hair drier. bear. bench. fire hydrant. baseball bat. teddy bear. pizza. vase. cow. donut. keyboard. train. bird. baseball glove. spoon. grass. tree. sizes. patch. rock. rock formation. ', 'regions': [{'bbox': [[86.29, 28.04, 345.17, 453.03000000000003], [304.27, 130.22, 444.59, 437.89], [460.01, 154.03, 534.81, 428.86]], 'phrase': 'giraffe', 'tokens_positive': [[97, 104]], 'attributes': {'Giraffe': ['"tall", "spotted pattern", "standing", "brown and white", "feeding area", "rocky enclosure", "three individuals", "outdoors"']}}]}}
# ['"black fur"', '"walking"', '"on grass"', '"large"', '"outdoors"', '"natural habitat"', '"rocks and foliage nearby"', '"in motion"']
# [Bear]: ["black fur"], ["walking"], ["on grass"], ["large"], ["outdoors"], ["natural habitat"], ["rocks and foliage nearby"], ["in motion"]
# ['"green", "short", "covered with fallen leaves"']
# [Grass]: ["green", "short", "covered with fallen leaves"]
# ['"fallen", "brown", "scattered", "on grass", "natural", "in foreground"']
# [Leaves]: ["fallen", "brown", "scattered", "on grass", "natural", "in foreground"]
# {'filename': '000000357386.jpg', 'height': 480, 'width': 640, 'conversations': [{'from': 'human', 'value': '\nProvide a scene graph caption of the given image.'}, {'from': 'gpt', 'value': 'In the image, a black bear is running on grass that is covered with fallen leaves. The bear is near some large rocks, which are on the grass. In the background, there are trees that are beside the rocks, creating a natural park-like setting.'}], 'tags': ['grass', 'leaves', 'caption'], 'grounding': {'caption': 'bowl. backpack. vase. tennis racket. bed. remote. oven. handbag. hot dog. banana. mouse. horse. bear. potted plant. dog. tv. fork. tie. hair drier. bicycle. carrot. chair. book. parking meter. motorcycle. couch. teddy bear. orange. toilet. donut. toothbrush. sheep. sandwich. cow. baseball bat. boat. cat. elephant. zebra. skis. dining table. frisbee. keyboard. traffic light. car. cell phone. sports ball. knife. baseball glove. apple. stop sign. bird. skateboard. cake. giraffe. umbrella. surfboard. wine glass. laptop. clock. kite. truck. cup. spoon. microwave. pizza. fire hydrant. refrigerator. snowboard. broccoli. train. bottle. bus. sink. airplane. toaster. bench. suitcase. person. scissors. grass. leaves. ', 'regions': [{'bbox': [143.46, 122.64, 393.71000000000004, 270.41], 'phrase': 'bear', 'tokens_positive': [[96, 100]], 'attributes': {'Bear': ['"black fur"', '"walking"', '"on grass"', '"large"', '"outdoors"', '"natural habitat"', '"rocks and foliage nearby"', '"in motion"']}}, {'bbox': [0.3125, 221.0, 639.0, 479.0], 'phrase': 'grass', 'tokens_positive': [[701, 706]], 'attributes': {'Grass': ['"green", "short", "covered with fallen leaves"']}}, {'bbox': [304.25, 102.75, 467.25, 170.25], 'phrase': 'leaves', 'tokens_positive': [[708, 714]], 'attributes': {'Leaves': ['"fallen", "brown", "scattered", "on grass", "natural", "in foreground"']}}]}}
# ['"herd grazing"', '"brown and white"', '"grassy field"', '"relaxed posture"', '"large horns"', '"green trees"', '"cloudy sky"', '"spread across field"']
# [Cow]: ["herd grazing"], ["brown and white"], ["grassy field"], ["relaxed posture"], ["large horns"], ["green trees"], ["cloudy sky"], ["spread across field"]
# ['"leafy green"', '"tall"', '"standing"', '"dense foliage"', '"various heights"', '"in background"', '"green"', '"grouped together"', '"behind grazing animals"']
# [Tree]: ["leafy green"], ["tall"], ["standing"], ["dense foliage"], ["various heights"], ["in background"], ["green"], ["grouped together"], ["behind grazing animals"]
# ['"cloudy"', '"blue"', '"overcast"', '"wide expanse"', '"above trees"', '"over field"']
# [Sky]: ["cloudy"], ["blue"], ["overcast"], ["wide expanse"], ["above trees"], ["over field"]
# ['"herd", "brown and white", "grazing", "large horns", "green grass field", "relaxed posture", "spread out", "trees in background"']
# [Cattle]: ["herd", "brown and white", "grazing", "large horns", "green grass field", "relaxed posture", "spread out", "trees in background"]
# ['"green"', '"evenly mowed"', '"wide expanse"', '"under animals"', '"natural landscape"', '"field"', '"foreground"', '"beneath trees"']
# [Grass]: ["green"], ["evenly mowed"], ["wide expanse"], ["under animals"], ["natural landscape"], ["field"], ["foreground"], ["beneath trees"]
# {'filename': '000000131390.jpg', 'height': 480, 'width': 640, 'conversations': [{'from': 'human', 'value': '\nProvide a scene graph caption of the given image.'}, {'from': 'gpt', 'value': 'In the image, a herd of cattle are lying on a grassy field. The cattle are resting in a meadow, and the scene is set against a backdrop of a tree on the grass and a sky over the tree. The peaceful setting suggests a tranquil day in the pasture.'}], 'tags': ['sky', 'backdrop', 'field', 'grass', 'tree', 'caption', 'herd', 'pasture', 'cattle', 'meadow'], 'grounding': {'caption': 'sandwich. knife. boat. cow. sheep. wine glass. cup. bus. mouse. skis. tie. giraffe. bed. toothbrush. hair drier. parking meter. refrigerator. bottle. bowl. fire hydrant. toilet. laptop. traffic light. train. cell phone. hot dog. bird. microwave. broccoli. elephant. handbag. dining table. grass. cattle. sky. tree. backdrop. field. herd. pasture. meadow. ', 'regions': [{'bbox': [[232.0, 310.99, 264.40999999999997, 342.12], [516.36, 300.08, 561.73, 332.90999999999997], [263.49, 315.91, 286.44, 339.38], [279.96, 308.95, 309.22999999999996, 336.90999999999997], [300.42, 317.2, 329.94, 336.78], [570.65, 300.06, 594.89, 323.9], [544.53, 292.27, 572.1999999999999, 313.02], [408.7, 299.0, 449.78, 332.63], [181.04, 306.97, 214.20999999999998, 333.73], [92.82, 300.07, 133.39, 328.21], [247.02, 293.68, 276.32, 318.01], [299.58, 308.36, 317.71, 319.61], [339.94, 319.37, 358.29, 334.21], [385.95, 310.12, 403.41999999999996, 328.25]], 'phrase': 'cow', 'tokens_positive': [[23, 26]], 'attributes': {'Cow': ['"herd grazing"', '"brown and white"', '"grassy field"', '"relaxed posture"', '"large horns"', '"green trees"', '"cloudy sky"', '"spread across field"']}}, {'bbox': [[400.75, 193.875, 523.5, 312.75], [155.625, 100.625, 332.75, 313.25], [502.5, 189.25, 580.0, 302.5], [575.5, 191.5, 640.0, 299.0], [0.25390625, 117.9375, 67.8125, 326.25]], 'phrase': 'tree', 'tokens_positive': [[309, 313]], 'attributes': {'Tree': ['"leafy green"', '"tall"', '"standing"', '"dense foliage"', '"various heights"', '"in background"', '"green"', '"grouped together"', '"behind grazing animals"']}}, {'bbox': [0.46875, 0.29296875, 639.0, 215.375], 'phrase': 'sky', 'tokens_positive': [[304, 307]], 'attributes': {'Sky': ['"cloudy"', '"blue"', '"overcast"', '"wide expanse"', '"above trees"', '"over field"']}}, {'bbox': [[498.0, 295.75, 522.5, 312.25], [156.75, 312.25, 183.125, 337.25], [320.25, 316.25, 341.0, 336.0], [360.5, 315.5, 389.25, 332.25], [608.5, 299.75, 630.0, 312.75], [391.25, 296.25, 419.0, 328.25], [532.0, 301.25, 558.5, 315.0], [592.5, 304.5, 609.5, 315.5], [629.5, 286.25, 640.0, 313.5], [313.5, 297.75, 346.0, 318.5], [344.75, 305.25, 370.75, 318.5], [125.625, 312.25, 164.375, 338.25], [211.25, 309.25, 234.875, 326.75]], 'phrase': 'cattle', 'tokens_positive': [[296, 302]], 'attributes': {'Cattle': ['"herd", "brown and white", "grazing", "large horns", "green grass field", "relaxed posture", "spread out", "trees in background"']}}, {'bbox': [0.46875, 310.25, 639.0, 478.75], 'phrase': 'grass', 'tokens_positive': [[289, 294]], 'attributes': {'Grass': ['"green"', '"evenly mowed"', '"wide expanse"', '"under animals"', '"natural landscape"', '"field"', '"foreground"', '"beneath trees"']}}]}}
# ['"two-wheeled", "black frame", "leaning against wall", "with kickstand extended", "on street"', '"red and white signboard nearby"', '"adjacent to storefront"', '"on right side of street"']
# [Bicycle]: ["two-wheeled", "black frame", "leaning against wall", "with kickstand extended", "on street"], ["red and white signboard nearby"], ["adjacent to storefront"], ["on right side of street"]
# ['"small", "black"', '"parked"', '"on street"', '"near building"', '"no visible logo"', '"adjacent to bicycles"']
# [Car]: ["small", "black"], ["parked"], ["on street"], ["near building"], ["no visible logo"], ["adjacent to bicycles"]
# ['"two-wheeled vehicle"', '"black body"', '"motorbike"', '"on street"', '"no visible brand"', '"in motion"', '"between buildings"', '"adjacent to pedestrians"']
# [Motorcycle]: ["two-wheeled vehicle"], ["black body"], ["motorbike"], ["on street"], ["no visible brand"], ["in motion"], ["between buildings"], ["adjacent to pedestrians"]
# ['"walking"', '"wearing casual clothing"', '"carrying bag"', '"on narrow street"', '"between buildings"', '"near bicycles"', '"with red sign"', '"on right side"']
# [Person]: ["walking"], ["wearing casual clothing"], ["carrying bag"], ["on narrow street"], ["between buildings"], ["near bicycles"], ["with red sign"], ["on right side"]
# ['"small rectangular"', '"blue"', '"on person\'s shoulder"', '"solid color"', '"no visible label"', '"being carried"', '"in the middle of street"']
# [Handbag]: ["small rectangular"], ["blue"], ["on person's shoulder"], ["solid color"], ["no visible label"], ["being carried"], ["in the middle of street"]
# ['"vertical"', '"red background"', '"white Japanese characters"', '"textured surface"', '"attached to building"', '"on left side"', '"prominent in frame"']
# [Signboard]: ["vertical"], ["red background"], ["white Japanese characters"], ["textured surface"], ["attached to building"], ["on left side"], ["prominent in frame"]
# ['"rectangular"', '"reflective glass"', '"white frame"', '"multiple panes"', '"advertisements"', '"on building facade"', '"above street level"', '"adjacent to storefronts"']
# [Window]: ["rectangular"], ["reflective glass"], ["white frame"], ["multiple panes"], ["advertisements"], ["on building facade"], ["above street level"], ["adjacent to storefronts"]
# ['"tilted"', '"dark gray"', '"supported by metal framework"', '"overhead"', '"urban setting"', '"adjacent to buildings"', '"with signage"']
# [Roof]: ["tilted"], ["dark gray"], ["supported by metal framework"], ["overhead"], ["urban setting"], ["adjacent to buildings"], ["with signage"]
# ['"multi-story"', '"commercial"', '"facade with signage"', '"various signs"', '"red and white"', '"exterior"', '"along street"', '"adjacent to street"']
# [Building]: ["multi-story"], ["commercial"], ["facade with signage"], ["various signs"], ["red and white"], ["exterior"], ["along street"], ["adjacent to street"]
# {'filename': '000000246074.jpg', 'height': 500, 'width': 376, 'conversations': [{'from': 'human', 'value': '\nProvide a scene graph caption of the given image.'}, {'from': 'gpt', 'value': 'In the image, we see an Asian street lined with various shops and signs on the buildings, creating a vibrant urban scene. The road itself has markings in Chinese characters, and there are multiple bicycles parked on the side of the road. A motorcycle is also visible among the parked vehicles.\n\nThere are people in the scene; one person is walking on the road, while another person is standing on the road and holding a handbag and wearing a tie. The light is over one of the bicycles, and a window is over a roof. The pavement runs alongside the road, and the building facades show a mix of traditional and modern architectural styles. The wall on the side adds to the urban texture of the scene. The street appears to be relatively empty, with only a few pedestrians and no heavy traffic.'}], 'tags': ['people', 'building', 'wall', 'street', 'light', 'window', 'road', 'caption', 'texture', 'roof', 'pavement', 'traffic'], 'grounding': {'caption': 'motorcycle. person. tie. handbag. banana. car. bicycle. roof. window. building. wall. street. light. road. texture. pavement. traffic. ', 'regions': [{'bbox': [[221.88, 159.42, 246.67, 186.54999999999998], [87.11, 369.41, 133.94, 435.41], [104.62, 247.32, 137.62, 285.62], [56.73, 444.86, 91.44, 499.20000000000005], [309.33, 344.11, 323.46999999999997, 406.15000000000003], [25.29, 450.66, 63.64, 500.0], [253.8, 236.93, 269.04, 281.37], [241.23, 173.13, 250.32, 201.15], [115.15, 303.39, 122.43, 322.75]], 'phrase': 'bicycle', 'tokens_positive': [[47, 54]], 'attributes': {'Bicycle': ['"two-wheeled", "black frame", "leaning against wall", "with kickstand extended", "on street"', '"red and white signboard nearby"', '"adjacent to storefront"', '"on right side of street"']}}, {'bbox': [[189.37, 40.82, 196.02, 46.76], [184.13, 36.4, 192.42, 41.17], [173.46, 40.16, 184.68, 55.15]], 'phrase': 'car', 'tokens_positive': [[42, 45]], 'attributes': {'Car': ['"small", "black"', '"parked"', '"on street"', '"near building"', '"no visible logo"', '"adjacent to bicycles"']}}, {'bbox': [260.14, 243.81, 300.68, 283.22], 'phrase': 'motorcycle', 'tokens_positive': [[0, 10]], 'attributes': {'Motorcycle': ['"two-wheeled vehicle"', '"black body"', '"motorbike"', '"on street"', '"no visible brand"', '"in motion"', '"between buildings"', '"adjacent to pedestrians"']}}, {'bbox': [[222.96, 181.86, 246.42000000000002, 224.02], [170.6, 87.09, 178.04, 106.9], [330.65, 439.24, 353.98999999999995, 499.98]], 'phrase': 'person', 'tokens_positive': [[12, 18]], 'attributes': {'Person': ['"walking"', '"wearing casual clothing"', '"carrying bag"', '"on narrow street"', '"between buildings"', '"near bicycles"', '"with red sign"', '"on right side"']}}, {'bbox': [223.3, 201.51, 228.42000000000002, 214.10999999999999], 'phrase': 'handbag', 'tokens_positive': [[25, 32]], 'attributes': {'Handbag': ['"small rectangular"', '"blue"', '"on person\'s shoulder"', '"solid color"', '"no visible label"', '"being carried"', '"in the middle of street"']}}, {'bbox': [234.3, 189.8, 236.99, 202.5], 'phrase': 'tie', 'tokens_positive': [[20, 23]], 'attributes': {'Signboard': ['"vertical"', '"red background"', '"white Japanese characters"', '"textured surface"', '"attached to building"', '"on left side"', '"prominent in frame"']}}, {'bbox': [[68.0, 86.375, 88.125, 171.25], [306.75, 185.75, 334.5, 292.75]], 'phrase': 'window', 'tokens_positive': [[62, 68]], 'attributes': {'Window': ['"rectangular"', '"reflective glass"', '"white frame"', '"multiple panes"', '"advertisements"', '"on building facade"', '"above street level"', '"adjacent to storefronts"']}}, {'bbox': [87.0, 179.125, 131.75, 232.0], 'phrase': 'roof', 'tokens_positive': [[56, 60]], 'attributes': {'Roof': ['"tilted"', '"dark gray"', '"supported by metal framework"', '"overhead"', '"urban setting"', '"adjacent to ...
# ['"jumping"', '"gray hoodie"', '"black pants"', '"black sneakers"', '"mid-air"', '"stacked wooden planks"', '"on floor"', '"performing trick"', '"group of spectators"']
# [Skateboarder]: ["jumping"], ["gray hoodie"], ["black pants"], ["black sneakers"], ["mid-air"], ["stacked wooden planks"], ["on floor"], ["performing trick"], ["group of spectators"]
# ['"black"', '"on person\'s back"', '"textured fabric"', '"partially visible"', '"on right side of image"']
# [Backpack]: ["black"], ["on person's back"], ["textured fabric"], ["partially visible"], ["on right side of image"]
# ['"black", "with white wheels"', '"being ridden by person mid-air"', '"stacked wooden blocks beneath"', '"in indoor setting"', '"underfoot of skateboarder"', '"skateboarder performing trick"']
# [Skateboard]: ["black", "with white wheels"], ["being ridden by person mid-air"], ["stacked wooden blocks beneath"], ["in indoor setting"], ["underfoot of skateboarder"], ["skateboarder performing trick"]
# ['"jumping"', '"gray hoodie"', '"black pants"', '"black sneakers"', '"mid-air"', '"stacked wooden planks"', '"on floor"', '"performing trick"', '"group of spectators"']
# [Skateboarder]: ["jumping"], ["gray hoodie"], ["black pants"], ["black sneakers"], ["mid-air"], ["stacked wooden planks"], ["on floor"], ["performing trick"], ["group of spectators"]
# ['"indoor", "smooth", "gray", "concrete", "reflective", "under skateboarder", "in hallway"']
# [Floor]: ["indoor", "smooth", "gray", "concrete", "reflective", "under skateboarder", "in hallway"]
# ['"stacked planks"', '"light brown"', '"rectangular"', '"flat surfaces"', '"uniform size"', '"on ground"', '"under skateboarder"', '"near group of people"']
# [Wood]: ["stacked planks"], ["light brown"], ["rectangular"], ["flat surfaces"], ["uniform size"], ["on ground"], ["under skateboarder"], ["near group of people"]
# ['"black", "with white wheels"', '"being used by skateboarder"', '"stacked wooden planks beneath"', '"in mid-air"', '"skateboarder performing trick"', '"on concrete floor"', '"near group of people"']
# [Skateboard]: ["black", "with white wheels"], ["being used by skateboarder"], ["stacked wooden planks beneath"], ["in mid-air"], ["skateboarder performing trick"], ["on concrete floor"], ["near group of people"]
# {'filename': '000000325956.jpg', 'height': 426, 'width': 640, 'conversations': [{'from': 'human', 'value': '\nProvide a scene graph caption of the given image.'}, {'from': 'gpt', 'value': 'In the image, a person is playing with a skateboard, performing a trick over a pile of wood on the floor. A group of young people are watching the action, with some standing on the floor and others leaning on the wall. One person is beside another, and there are several backpacks visible on the floor, suggesting that this may be a school or similar setting. The ceiling is over the floor and also over the person on the skateboard. A light fixture is attached to the ceiling, illuminating the indoor space.'}], 'tags': ['people', 'wall', 'floor', 'space', 'action', 'caption', 'ceiling', 'wood', 'trick', 'pile', 'fixture', 'school'], 'grounding': {'caption': 'potted plant. skis. motorcycle. laptop. clock. parking meter. elephant. keyboard. skateboard. dining table. baseball bat. giraffe. surfboard. dog. bird. wine glass. baseball glove. teddy bear. handbag. mouse. toothbrush. toilet. umbrella. vase. backpack. hot dog. book. bench. scissors. kite. traffic light. boat. frisbee. bottle. truck. chair. bear. couch. sandwich. apple. donut. cup. fire hydrant. tie. cell phone. hair drier. refrigerator. horse. tv. sports ball. cake. remote. zebra. pizza. sheep. person. microwave. snowboard. knife. carrot. airplane. sink. bicycle. tennis racket. suitcase. broccoli. oven. train. orange. cow. stop sign. cat. bus. spoon. toaster. bowl. bed. car. banana. fork. fixture. people. floor. wood. wall. space. action. ceiling. trick. school. ', 'regions': [{'bbox': [[2.88, 3.36, 289.76, 219.24], [200.83, 143.82, 254.52, 362.35], [284.32, 165.61, 349.41999999999996, 318.78], [342.2, 130.86, 389.0, 345.3], [248.9, 171.36, 289.11, 307.29], [547.14, 53.19, 635.22, 339.45], [333.86, 117.45, 405.22, 352.48], [393.45, 93.82, 460.46, 350.37], [451.91, 80.11, 537.3000000000001, 353.56], [49.62, 221.89, 87.84, 362.91999999999996], [12.23, 245.05, 44.05, 363.91], [81.96, 197.28, 109.88999999999999, 263.40999999999997], [0.0, 250.12, 18.64, 369.95]], 'phrase': 'person', 'tokens_positive': [[503, 509]], 'attributes': {'Skateboarder': ['"jumping"', '"gray hoodie"', '"black pants"', '"black sneakers"', '"mid-air"', '"stacked wooden planks"', '"on floor"', '"performing trick"', '"group of spectators"']}}, {'bbox': [[302.56, 309.6, 336.06, 353.8], [575.52, 159.49, 640.0, 234.01], [250.98, 291.81, 313.71999999999997, 361.15999999999997]], 'phrase': 'backpack', 'tokens_positive': [[245, 253]], 'attributes': {'Backpack': ['"black"', '"on person\'s back"', '"textured fabric"', '"partially visible"', '"on right side of image"']}}, {'bbox': [100.36, 192.03, 205.17000000000002, 250.35], 'phrase': 'skateboard', 'tokens_positive': [[82, 92]], 'attributes': {'Skateboard': ['"black", "with white wheels"', '"being ridden by person mid-air"', '"stacked wooden blocks beneath"', '"in indoor setting"', '"underfoot of skateboarder"', '"skateboarder performing trick"']}}, {'bbox': [[146.25, 152.5, 175.0, 198.5], [341.75, 131.125, 365.0, 161.5]], 'phrase': 'people', 'tokens_positive': [[710, 716]], 'attributes': {'Skateboarder': ['"jumping"', '"gray hoodie"', '"black pants"', '"black sneakers"', '"mid-air"', '"stacked wooden planks"', '"on floor"', '"performing trick"', '"group of spectators"']}}, {'bbox': [0.3125, 325.25, 639.5, 424.75], 'phrase': 'floor', 'tokens_positive': [[718, 723]], 'attributes': {'Floor': ['"indoor", "smooth", "gray", "concrete", "reflective", "under skateboarder", "in hallway"']}}, {'bbox': [[82.25, 369.5, 206.875, 391.5], [81.875, 245.5, 207.0, 391.5], [86.25, 348.0, 193.875, 367.5], [83.125, 326.5, 192.375, 344.75], [91.375, 286.75, 174.75, 302.25], [107.5, 360.75, 184.125, 377.5], [99.6875, 337.75, 185.5, 353.25]], 'phrase': 'wood', 'tokens_positive': [[725, 729]], 'attributes': {'Wood': ['"stacked planks"', '"light brown"', '"rectangular"', '"flat surfaces"', '"uniform size ...
# ['"small", "brown", "standing on inflatable boat"', '"furry"', '"on motorboat"', '"near person"', '"next to motor"', '"in water"']
# [Dog]: ["small", "brown", "standing on inflatable boat"], ["furry"], ["on motorboat"], ["near person"], ["next to motor"], ["in water"]
# ['"motorized"', '"gray with black trim"', '"in water"', '"man steering"', '"dog sitting"', '"portable"', '"in marina"', '"near docked sailboats"']
# [Inflatable Boat]: ["motorized"], ["gray with black trim"], ["in water"], ["man steering"], ["dog sitting"], ["portable"], ["in marina"], ["near docked sailboats"]
# ['"in small motorboat"', '"wearing dark jacket"', '"holding motor control"', '"sitting"', '"blue and black"', '"on water"', '"near docked boats"']
# [Person]: ["in small motorboat"], ["wearing dark jacket"], ["holding motor control"], ["sitting"], ["blue and black"], ["on water"], ["near docked boats"]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 161
#     158         print(f"已处理 {processed_count}/{total_annotations} 个标注 ({progress:.2f}%)")
#     160 if __name__ == '__main__':
# --> 161     main()
#
# Cell In[10], line 154, in main()
#     151     pass
#     153 for batch in read_jsonl_batch(file_path, batch_size):
# --> 154     update_jsonl_batch(batch, image_base_path, output_file_path)
#     156     processed_count += len(batch)
#     157     progress = (processed_count / total_annotations) * 100
#
# Cell In[10], line 128, in update_jsonl_batch(data, image_base_path, output_file_path)
#     126 for region in item['grounding']['regions']:
#     127     phrase = region['phrase']
# --> 128     attributes_text = identify_attributes(phrase, image_path)
#     129     attribute_dict = parse_attributes(attributes_text)
#     130     print(attributes_text)
#
# Cell In[10], line 83, in identify_attributes(tags, image_path)
#      74 inputs = processor(
#      75     text=[text],
#      76     images=image_inputs,
#    (...)
#      79     return_tensors="pt",
#      80 )
#      81 inputs = inputs.to(model.device)
# ---> 83 generated_ids = model.generate(**inputs, max_new_tokens=128)
#      84 generated_ids_trimmed = [
#      85     out_ids[len(in_ids):] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
#      86 ]
#      87 output_text = processor.batch_decode(
#      88     generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
#      89 )
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/generation/utils.py:2228, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2220     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2221         input_ids=input_ids,
#    2222         expand_size=generation_config.num_return_sequences,
#    2223         is_encoder_decoder=self.config.is_encoder_decoder,
#    2224         **model_kwargs,
#    2225     )
#    2227     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2228     result = self._sample(
#    2229         input_ids,
#    2230         logits_processor=prepared_logits_processor,
#    2231         stopping_criteria=prepared_stopping_criteria,
#    2232         generation_config=generation_config,
#    2233         synced_gpus=synced_gpus,
#    2234         streamer=streamer,
#    2235         **model_kwargs,
#    2236     )
#    2238 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2239     # 11. prepare beam search scorer
#    2240     beam_scorer = BeamSearchScorer(
#    2241         batch_size=batch_size,
#    2242         num_beams=generation_config.num_beams,
#    (...)
#    2247         max_length=generation_config.max_length,
#    2248     )
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/generation/utils.py:3212, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3210     is_prefill = False
#    3211 else:
# -> 3212     outputs = model_forward(**model_inputs, return_dict=True)
#    3214 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3215 model_kwargs = self._update_model_kwargs_for_generation(
#    3216     outputs,
#    3217     model_kwargs,
#    3218     is_encoder_decoder=self.config.is_encoder_decoder,
#    3219 )
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/qwen2_5_vl/modeling_qwen2_5_vl.py:1808, in Qwen2_5_VLForConditionalGeneration.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, pixel_values, pixel_values_videos, image_grid_thw, video_grid_thw, rope_deltas, cache_position, second_per_grid_ts)
#    1805         position_ids = position_ids.add(delta)
#    1806         position_ids = position_ids.unsqueeze(0).expand(3, -1, -1)
# -> 1808 outputs = self.model(
#    1809     input_ids=None,
#    1810     position_ids=position_ids,
#    1811     attention_mask=attention_mask,
#    1812     past_key_values=past_key_values,
#    1813     inputs_embeds=inputs_embeds,
#    1814     use_cache=use_cache,
#    1815     output_attentions=output_attentions,
#    1816     output_hidden_states=output_hidden_states,
#    1817     return_dict=return_dict,
#    1818     cache_position=cache_position,
#    1819 )
#    1821 hidden_states = outputs[0]
#    1822 logits = self.lm_head(hidden_states)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/qwen2_5_vl/modeling_qwen2_5_vl.py:1155, in Qwen2_5_VLModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1143     layer_outputs = self._gradient_checkpointing_func(
#    1144         decoder_layer.__call__,
#    1145         hidden_states,
#    (...)
#    1152         position_embeddings,
#    1153     )
#    1154 else:
# -> 1155     layer_outputs = decoder_layer(
#    1156         hidden_states,
#    1157         attention_mask=causal_mask,
#    1158         position_ids=position_ids,
#    1159         past_key_value=past_key_values,
#    1160         output_attentions=output_attentions,
#    1161         use_cache=use_cache,
#    1162         cache_position=cache_position,
#    1163         position_embeddings=position_embeddings,
#    1164     )
#    1166 hidden_states = layer_outputs[0]
#    1168 if use_cache:
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/qwen2_5_vl/modeling_qwen2_5_vl.py:1031, in Qwen2_5_VLDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#    1029 # Fully Connected
#    1030 residual = hidden_states
# -> 1031 hidden_states = self.post_attention_layernorm(hidden_states)
#    1032 hidden_states = self.mlp(hidden_states)
#    1033 hidden_states = residual + hidden_states
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/lib/python3.12/site-packages/transformers/models/qwen2_5_vl/modeling_qwen2_5_vl.py:139, in Qwen2RMSNorm.forward(self, hidden_states)
#     137 input_dtype = hidden_states.dtype
#     138 hidden_states = hidden_states.to(torch.float32)
# --> 139 variance = hidden_states.pow(2).mean(-1, keepdim=True)
#     140 hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)
#     141 return self.weight * hidden_states.to(input_dtype)
#
# KeyboardInterrupt:

# %%
Prompt for Image Object Description with Attribute Priority:

When describing objects in the given image, follow these attribute priority guidelines and rule constraints to ensure a clear and concise description:

Attribute Priority (Ordered by Visual Distinctiveness):

Object Type/Subcategory: Clearly identify the main type or subcategory of the object (e.g., smartphone, hardcover book).
Appearance: Describe the shape, size, and any notable features of the object that make it visually distinct (e.g., rectangular, elongated, with a rounded top).
Material/Texture: Mention the material or texture of the object if it is clearly visible (e.g., glossy, matte, fabric, metallic).
Components: Note any attached parts or components that are part of the object (e.g., a strap on a handbag, buttons on a shirt).
Color Scheme: Describe the dominant colors or patterns of the object (e.g., red and black, striped, solid color).
Interaction Status: If applicable, describe how the object is being used or its current state (e.g., held, open, lying flat).
Surface Text/Graphics: Mention any visible logos, labels, or graphics on the object's surface.
Adjacent Objects: Only include descriptions of core adjacent objects that have a stable positional relationship with the main object (e.g., a laptop next to a mouse).

Rule Constraints:
                                                                                                                                      
Select Most Prominent Visual Attributes: From the 8 attribute categories, choose only the most visually striking and distinct attributes for each object. You do not need to use all 8 categories for every object; prioritize based on visual distinctiveness.
Explicitly Visible Attributes: Only include attributes that are clearly visible in the image. Avoid speculative or inferred descriptions.
No Negative Descriptions: Do not include statements that indicate the absence of a feature (e.g., "no visible label").
Single Most Prominent Instance: For multiple instances of the same object category, describe only the most prominent instance based on size, clarity of features, or frame occupancy.
Stable Positional Relationships: When mentioning adjacent objects, ensure they have a stable and meaningful positional relationship with the main object.
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /root
